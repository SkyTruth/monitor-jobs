# %% [markdown]
# ### Testing python imports
#
# This notebook is for testing python dependency imports

# %%
import os
import sys
import glob
from datetime import datetime
from pathlib import Path

import psycopg2
import argparse
import google_crc32c
import smtplib
from smtplib import SMTPException
from smtplib import SMTP              # sending email
from jinja2 import Environment        # Jinja2 templating
from urllib.parse import urlparse, parse_qs
import re
from email.mime.text import MIMEText
import unicodedata
import requests
from googleapiclient.discovery import build
from oauth2client.service_account import ServiceAccountCredentials
from googleapiclient.http import MediaIoBaseDownload

# %%
import rasterio
import rasterio.warp
from rasterio.crs import CRS
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ebeva\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\ebeva\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\ebeva\AppData\Local\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ebeva\AppData\Local\Temp\ipykernel_17236\1039751227.py", line 1, in <module>
#     import rasterio
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\rasterio\__init__.py", line 68, in <module>
#     from rasterio.io import (
#   File "c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\rasterio\io.py", line 9, in <module>
#     from rasterio._io import (
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import rasterio
#       2 import rasterio.warp
#       3 from rasterio.crs import CRS
#
# File c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\rasterio\__init__.py:68
#      62 from rasterio.env import ensure_env_with_credentials, Env
#      63 from rasterio.errors import (
#      64     RasterioIOError,
#      65     DriverCapabilityError,
#      66     RasterioDeprecationWarning,
#      67 )
# ---> 68 from rasterio.io import (
#      69     DatasetReader,
#      70     get_writer_for_path,
#      71     get_writer_for_driver,
#      72     MemoryFile,
#      73 )
#      74 from rasterio.profiles import default_gtiff_profile
#      75 from rasterio.transform import Affine, guard_transform
#
# File c:\Users\ebeva\AppData\Local\pypoetry\Cache\virtualenvs\monitor-jobs-kusWDpVk-py3.11\Lib\site-packages\rasterio\io.py:9
#       6 import logging
#       8 from rasterio._base import get_dataset_driver, driver_can_create, driver_can_create_copy
# ----> 9 from rasterio._io import (
#      10     DatasetReaderBase,
#      11     DatasetWriterBase,
#      12     BufferedDatasetWriterBase,
#      13     MemoryFileBase,
#      14 )
#      15 from rasterio.windows import WindowMethodsMixin
#      16 from rasterio.env import Env, ensure_env
#
# File rasterio\\_io.pyx:1, in init rasterio._io()
#
# ImportError: numpy.core.multiarray failed to import (auto-generated because you didn't call 'numpy.import_array()' after cimporting numpy; use '<void>numpy._import_array' to disable if you are certain you don't need it).
